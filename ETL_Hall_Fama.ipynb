# %%
# Bibliotecas
import pandas as pd

# %%
# Leitura dos dataframes
df1 = pd.read_csv("./dados_brutos/data_1.csv")
df2 = pd.read_csv("./dados_brutos/data_2.csv")
df3 = pd.read_csv("./dados_brutos/data_3.csv")
df4 = pd.read_csv("./dados_brutos/data_4.csv")
